# %% [markdown]
# # Local Binary Patterns
#
# http://scikit-image.org/docs/dev/api/skimage.feature.html#skimage.feature.local_binary_pattern
# http://scikit-image.org/docs/dev/auto_examples/features_detection/plot_local_binary_pattern.html

# %%
# %matplotlib inline

# %%
import numpy as np
import cv2 
import matplotlib
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data, color, exposure
import skimage.feature as ft
import scipy.ndimage as nd
from scipy.stats import itemfreq

# %% [markdown]
# # Carrega imagens de referencia
#
# ## Estas imagens, já são áreas de interesse: Tijolos, Grama, Parede

# %%
brick = data.load('brick.png')
grass = data.load('grass.png')
wall = data.load('rough-wall.png')

#mostra imagens
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 4))
  
ax1.axis('off')
ax1.imshow(brick, cmap=plt.cm.gray)
ax1.set_title('Brick')
  
ax2.axis('off')
ax2.imshow(grass, cmap=plt.cm.gray)
ax2.set_title('Grass')

ax3.axis('off')
ax3.imshow(wall, cmap=plt.cm.gray)
ax3.set_title('Wall')

plt.show()

# %% [markdown]
# # Calcula o LBP para cada imagem

# %%
# settings for LBP
METHOD = 'uniform'
P = 16 # número de vizinhos
R = 2 # raio

refs = {
    'brick': ft.local_binary_pattern(brick, P, R, METHOD),
    'grass': ft.local_binary_pattern(grass, P, R, METHOD),
    'wall': ft.local_binary_pattern(wall, P, R, METHOD)
}

#mostra imagens e histograma
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3,
                                                       figsize=(9, 6))
  
ax1.axis('off')
ax1.imshow(refs['brick'], cmap=plt.cm.gray)
ax1.set_title('Brick')
  
ax2.axis('off')
ax2.imshow(refs['grass'], cmap=plt.cm.gray)
ax2.set_title('Grass')

ax3.axis('off')
ax3.imshow(refs['wall'], cmap=plt.cm.gray)
ax3.set_title('Wall')


ax4.hist(refs['brick'].ravel(), normed=True, bins=P + 2, range=(0, P + 2))
ax4.set_ylabel('Percentage')
ax5.hist(refs['grass'].ravel(), normed=True, bins=P + 2, range=(0, P + 2))
ax5.set_xlabel('Uniform LBP values')
ax6.hist(refs['wall'].ravel(), normed=True, bins=P + 2, range=(0, P + 2))

plt.show()

# %% [markdown]
# # Agora vamos calcular a similaridade dos histogramas
#
# ## Para isso, primeiro:
#
# * Extraimos a frequencia dos valores com o método ** itemfreq **
# * Normatizamos ente 0 e 1:   x/sum()

# %%
def CalcHistogram(lbpImage):
    freq = itemfreq(lbpImage.ravel())
    hist = freq / sum(freq)
    return np.array(hist, dtype=np.float32)

#print( CalcHistogram(refs['brick']) )
#print( CalcHistogram(refs['grass']) )

# %% [markdown]
# # Comparando as três imagens
#
# Quanto MENOR o score, MELHOR

# %%
def Compare(nome, lbpImage):
    
    #CV_COMP_CORREL Correlation
    #CV_COMP_CHISQR Chi-Square
    #CV_COMP_INTERSECT Intersection
    #CV_COMP_BHATTACHARYYA Bhattacharyya distance

    score1 = cv2.compareHist(CalcHistogram(lbpImage), CalcHistogram(refs['brick']), cv2.HISTCMP_CHISQR)
    score2 = cv2.compareHist(CalcHistogram(lbpImage), CalcHistogram(refs['grass']), cv2.HISTCMP_CHISQR)
    score3 = cv2.compareHist(CalcHistogram(lbpImage), CalcHistogram(refs['wall']), cv2.HISTCMP_CHISQR)
    
    print()
    print("Comparando %s com as imagens"%nome, " (",score1,",", score2,",", score3,")")
    
    if (score1 < score2 and score1 < score3):
        print("É BRICK")
    
    if (score2 < score1 and score2 < score3):
        print("É GRASS")
    
    if (score3 < score1 and score3 < score2):
        print("É WALL")    
        
Compare("BRICKS", refs['brick'])    
Compare("GRASS", refs['grass'])    
Compare("WALL", refs['wall'])
# Out:
# Comparando BRICKS com as imagens  ( 0.0 , 0.13791370718375934 , 0.2808862781185515 )
# É BRICK
#
# Comparando GRASS com as imagens  ( 0.09090442734524364 , 0.0 , 0.09879813369922708 )
# É GRASS
#
# Comparando WALL com as imagens  ( 0.17514341723007276 , 0.07224821123521546 , 0.0 )
# É WALL

# %%
import os

path_0 = "./images/grass/"

for filename in os.listdir(path_0):
    img = cv2.imread(os.path.join(path_0, filename))
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    lbpImage = ft.local_binary_pattern(image, P, R, METHOD)
    Compare(filename, lbpImage)
# Out:
# Comparando Grass (1).jpg com as imagens  ( 0.41971541637200194 , 0.2284448491308668 , 0.717219085202657 )
# É GRASS
#
# Comparando Grass (1).png com as imagens  ( 0.36091437342122445 , 0.35521965512034154 , 0.9424035701494022 )
# É GRASS
#
# Comparando Grass (2).jpg com as imagens  ( 0.7624979003534377 , 0.5268656622200187 , 1.4366486850753197 )
# É GRASS
#
# Comparando Grass (3).jpg com as imagens  ( 0.8210220720114771 , 0.5552885730673599 , 1.5157724704255524 )
# É GRASS
#
# Comparando Grass (4).jpg com as imagens  ( 0.47213051480095664 , 0.31455299401680303 , 0.9744525114390049 )
# É GRASS
#
# Comparando Grass (5).jpg com as imagens  ( 0.7834747887455711 , 0.5273156928403487 , 1.4703294339830684 )
# É GRASS
#
# Comparando Grass (6).jpg com as imagens  ( 0.9333969594823069 , 0.6355591777909904 , 1.64920707848301 )
# É GRASS
#
# Comparando Grass (7).jpg com as imagens  ( 1.7399658034657277 , 1.2752016021451489 , 3.022283862141687 )
# É GRASS
#
# Comparando Grass (8).jpg com as imagens  ( 1.3501197095910824 , 0.9494528347113248 , 2.347345868528029 )
# É GRASS

# %%
path_0 = "./images/brick/"

for filename in os.listdir(path_0):
    img = cv2.imread(os.path.join(path_0, filename))
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    lbpImage = ft.local_binary_pattern(image, P, R, METHOD)
    Compare(filename, lbpImage)
# Out:
# Comparando Brick (1).jpg com as imagens  ( 0.09186794294000032 , 0.14782243532285674 , 0.3891347149404894 )
# É BRICK
#
# Comparando Brick (2).jpg com as imagens  ( 0.06486072461607709 , 0.21373978723295195 , 0.5536924841383253 )
# É BRICK
#
# Comparando Brick (3).jpg com as imagens  ( 0.23535365635324068 , 0.4920797572677104 , 1.1333215099615264 )
# É BRICK
#
# Comparando Brick (4).jpg com as imagens  ( 0.1575717496445739 , 0.2072991239174088 , 0.531693510443098 )
# É BRICK
#
# Comparando Brick (5).jpg com as imagens  ( 0.016983302665943802 , 0.21326028185940263 , 0.3772903288613599 )
# É BRICK
#
# Comparando Brick (6).jpg com as imagens  ( 0.02118296880083035 , 0.060805115913472964 , 0.15183227748416425 )
# É BRICK
#
# Comparando Brick (7).jpg com as imagens  ( 0.025637172675080578 , 0.1310123308905031 , 0.36813175918493035 )
# É BRICK
#
# Comparando Brick (8).jpg com as imagens  ( 0.36275852648497464 , 0.8452799266626849 , 1.6063112721539248 )
# É BRICK
#
# Comparando Brick (9).jpg com as imagens  ( 0.24985706482995734 , 0.282635734298446 , 0.7217889413356481 )
# É BRICK

# %%
path_0 = "./images/wall/"

for filename in os.listdir(path_0):
    img = cv2.imread(os.path.join(path_0, filename))
    image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    lbpImage = ft.local_binary_pattern(image, P, R, METHOD)
    Compare(filename, lbpImage)
# Out:
# Comparando 222.jpg com as imagens  ( 0.5411525901312736 , 0.4932424940674959 , 1.298056538670217 )
# É GRASS
#
# Comparando 26f3240c45021986f36db1e93caeb094--tiling.jpg com as imagens  ( 0.32127481357522275 , 0.21418310320353856 , 0.745140762044309 )
# É GRASS
#
# Comparando 38251f6b7cf28c147874cdea81380f3d.jpg com as imagens  ( 0.10144170119335397 , 0.11452532320222394 , 0.3532173558810667 )
# É BRICK
#
# Comparando beige-rough-rock-orange-light-spots-shades-of-grey-color-stone-uneven-inconsistent-hard-material-squared-seamless-texture-512x512.jpg com as imagens  ( 0.2953033462992231 , 0.1370077183449833 , 0.49095220574018145 )
# É GRASS
#
# Comparando download.jpg com as imagens  ( 0.31688402204855604 , 0.16076794121500612 , 0.5311712464295543 )
# É GRASS
#
# Comparando green-mountain-wall-seamless-texture-rough-hard-moldy-solid-rock-surface-512x512.jpg com as imagens  ( 0.1590084271030996 , 0.03993175684729738 , 0.1880027463915131 )
# É GRASS
#
# Comparando grey-stone-concrete-wall-with-small-rough-stones-manmade-porous-surface-solid-material-huge-seamless-squared-texture-512x512.jpg com as imagens  ( 0.5084649549396745 , 0.3001036286442054 , 0.8865055336063333 )
# É GRASS
#
# Comparando images.jpg com as imagens  ( 3.9449809142193755 , 3.321785288149988 , 7.261189371050917 )
# É GRASS
#
# Comparando tile gold shiny.jpg com as imagens  ( 0.20738779154156597 , 0.19350795586995384 , 0.524940124943361 )
# É GRASS
#
# Comparando tile rough wall.jpg com as imagens  ( 0.14439396020404793 , 0.08331526615762715 , 0.3417410603677165 )
# É GRASS
#
# Comparando tile silver shiny3.jpg com as imagens  ( 0.5149567033966705 , 0.40845545675126355 , 1.0453379593971814 )
# É GRASS
#
# Comparando x2artist_Roughness.jpg com as imagens  ( 1.5267624222061191 , 1.245954817857898 , 2.5890108551180537 )
# É GRASS
